# %%
import json
import sqlite3
import pandas as pd
import numpy as np

# %% [markdown]
# Download latest version from [jmdict-simplified](https://github.com/scriptin/jmdict-simplified/releases)

# %%
filename = "jmdict-eng-3.6.1.json"

# %%
with open(filename, encoding="utf-8") as f:
    dict_data = json.load(f)

# %%
dict_data.keys()
# Out:
# dict_keys(['version', 'languages', 'commonOnly', 'dictDate', 'dictRevisions', 'tags', 'words'])

# %%
len(dict_data["words"])
# Out:
# 211090

# %%
dict_data["version"], dict_data["dictDate"]
# Out:
# ('3.6.1', '2025-03-03')

# %% [markdown]
# ## jlpt

# %% [markdown]
# Download jlpt data from [yomitan-jlpt-vocab
# Public
# ](https://github.com/stephenmk/yomitan-jlpt-vocab)

# %%
jlpt = {}
for i in range(5, 0, -1):
    print(i, len(pd.read_csv(f"n{i}.csv")))
    jlpt[f"n{i}"] = {
        "kanji": set(pd.read_csv(f"n{i}.csv")["kanji"].to_list()),
        "kana": set(pd.read_csv(f"n{i}.csv")["kana"].to_list()),
    }
# Out:
# 5 684
# 4 640
# 3 1730
# 2 1812
# 1 3427

# %% [markdown]
# ## To DB

# %% [markdown]
# create index from token/word -> dictionary entry

# %%
index = dict()
for i, word in enumerate(dict_data["words"]):
    for token in word["kanji"] + word["kana"]:
        key = token["text"]
        index.setdefault(key, []).append(i)

# %%
len(index)
# Out:
# 444913

# %% [markdown]
# write jlpt, index, and dictionary data

# %%
conn = sqlite3.connect('gari.db')
cursor = conn.cursor()

# %%
cursor.execute('''
    CREATE TABLE IF NOT EXISTS DictionaryMeta (
        key TEXT PRIMARY KEY,
        value TEXT
    );
''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Dictionary (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        data TEXT,
        jlpt INTEGER DEFAULT 0,
        isCommon INTEGER DEFAULT 0
    );
''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS DictionaryIndex (
        word TEXT,
        dicId INTEGER,
        
        PRIMARY KEY(word, dicId),
        FOREIGN KEY(dicId) REFERENCES Dictionary(id) ON DELETE CASCADE
    );
''')

# %% [markdown]
# insert meta data

# %%
cursor.execute('''
    INSERT OR REPLACE INTO DictionaryMeta (key, value)
    VALUES (?, ?);
''', ("version", dict_data["version"]))
cursor.execute('''
    INSERT OR REPLACE INTO DictionaryMeta (key, value)
    VALUES (?, ?);
''', ("date", dict_data["dictDate"]))

# %% [markdown]
# insert words indo dictionary, keep it as a json object. Add jlpt information and isCommon (for sorting)

# %%
for i, word in enumerate(dict_data["words"]):
    level = 0
    isCommon = False
    if len(word["kanji"]) == 0:
        isCommon = isCommon or word["kana"][0]["common"] 
        for n in range(5, 0, -1):
            if word["kana"][0]["text"] in jlpt[f"n{n}"]["kana"]:
                level = max(level, n)
    else:
        isCommon = isCommon or word["kanji"][0]["common"] 
        for n in range(5, 0, -1):
            if word["kanji"][0]["text"] in jlpt[f"n{n}"]["kanji"]:
                level = max(level, n)
    entry_json = json.dumps(word, ensure_ascii=False)
    cursor.execute('''
        INSERT OR IGNORE INTO Dictionary (id, data, jlpt, isCommon)
        VALUES (?, ?, ?, ?);
    ''', (i, entry_json, level, isCommon))
conn.commit()

# %% [markdown]
# insert dictionary index

# %%
for key, value in index.items():
    for dicId in value:
        cursor.execute('''
            INSERT OR IGNORE INTO DictionaryIndex (word, dicId)
            VALUES (?, ?);
        ''', (key, dicId))
conn.commit()

# %%
conn.close()

print("Database successfully created with dictionary entries.")
# Out:
# Database successfully created with dictionary entries.

# %%
words_applies_to_kanji = []
for i, word in enumerate(words_multi_reading):
    add = True
    for kana in word["kana"]:
        if len(kana["appliesToKanji"]) == 0 or kana["appliesToKanji"][0] == '*':
            add = False
    if add:
        words_applies_to_kanji.append(word)

# %%
len(words_applies_to_kanji), len(words_multi_reading)
# Out:
# (1631, 63131)

# %%
words_applies_to_kanji
# Out:
# [{'id': '1000110',
#   'kanji': [{'common': True, 'text': 'ＣＤプレーヤー', 'tags': []},
#    {'common': False, 'text': 'ＣＤプレイヤー', 'tags': []}],
#   'kana': [{'common': True,
#     'text': 'シーディープレーヤー',
#     'tags': [],
#     'appliesToKanji': ['ＣＤプレーヤー']},
#    {'common': False,
#     'text': 'シーディープレイヤー',
#     'tags': [],
#     'appliesToKanji': ['ＣＤプレイヤー']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'CD player'}]}]},
#  {'id': '1001510',
#   'kanji': [{'common': False, 'text': '御襁褓気触れ', 'tags': []},
#    {'common': False, 'text': 'お襁褓気触れ', 'tags': []},
#    {'common': False, 'text': 'オムツ気触れ', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'おむつかぶれ',
#     'tags': [],
#     'appliesToKanji': ['御襁褓気触れ', 'お襁褓気触れ']},
#    {'common': False,
#     'text': 'オムツかぶれ',
#     'tags': [],
#     'appliesToKanji': ['オムツ気触れ']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'diaper rash'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'nappy rash'}]}]},
#  {'id': '1003720',
#   'kanji': [{'common': False, 'text': 'くすくす笑う', 'tags': []},
#    {'common': False, 'text': 'クスクス笑う', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'くすくすわらう',
#     'tags': [],
#     'appliesToKanji': ['くすくす笑う']},
#    {'common': False,
#     'text': 'クスクスわらう',
#     'tags': [],
#     'appliesToKanji': ['クスクス笑う']}],
#   'sense': [{'partOfSpeech': ['exp', 'v5u'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to giggle'}]}]},
#  {'id': '1004000',
#   'kanji': [{'common': False, 'text': 'クンクン鳴く', 'tags': []},
#    {'common': False, 'text': 'くんくん鳴く', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'クンクンなく',
#     'tags': [],
#     'appliesToKanji': ['クンクン鳴く']},
#    {'common': False,
#     'text': 'くんくんなく',
#     'tags': [],
#     'appliesToKanji': ['くんくん鳴く']}],
#   'sense': [{'partOfSpeech': ['exp', 'v5k'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to whine (of a dog)'}]}]},
#  {'id': '1004220',
#   'kanji': [{'common': False, 'text': 'ケラケラ笑う', 'tags': []},
#    {'common': False, 'text': 'けらけら笑う', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ケラケラわらう',
#     'tags': [],
#     'appliesToKanji': ['ケラケラ笑う']},
#    {'common': False,
#     'text': 'けらけらわらう',
#     'tags': [],
#     'appliesToKanji': ['けらけら笑う']}],
#   'sense': [{'partOfSpeech': ['v5u', 'vi'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to cackle'}]}]},
#  {'id': '1004270',
#   'kanji': [{'common': False, 'text': 'ゲラゲラ笑う', 'tags': []},
#    {'common': False, 'text': 'げらげら笑う', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ゲラゲラわらう',
#     'tags': [],
#     'appliesToKanji': ['ゲラゲラ笑う']},
#    {'common': False,
#     'text': 'げらげらわらう',
#     'tags': [],
#     'appliesToKanji': ['げらげら笑う']}],
#   'sense': [{'partOfSpeech': ['exp', 'v5u'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to guffaw'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to roar with laughter'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to laugh heartily'}]}]},
#  {'id': '1004300',
#   'kanji': [{'common': False, 'text': 'ゲンを担ぐ', 'tags': []},
#    {'common': False, 'text': '験を担ぐ', 'tags': []},
#    {'common': False, 'text': 'げんを担ぐ', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ゲンをかつぐ',
#     'tags': [],
#     'appliesToKanji': ['ゲンを担ぐ']},
#    {'common': False,
#     'text': 'げんをかつぐ',
#     'tags': [],
#     'appliesToKanji': ['験を担ぐ', 'げんを担ぐ']}],
#   'sense': [{'partOfSpeech': ['exp', 'v5g'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to be superstitious'}]}]},
#  {'id': '1004430',
#   'kanji': [{'common': False, 'text': 'こそ泥', 'tags': []},
#    {'common': False, 'text': 'コソ泥', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'こそどろ',
#     'tags': [],
#     'appliesToKanji': ['こそ泥']},
#    {'common': False, 'text': 'コソどろ', 'tags': [], 'appliesToKanji': ['コソ泥']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['こそこそ泥棒']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['abbr'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'sneak thief'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'petty thief'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'cat burglar'}]}]},
#  {'id': '1005000',
#   'kanji': [{'common': False, 'text': 'ゴミ入れ', 'tags': []},
#    {'common': False, 'text': 'ごみ入れ', 'tags': []},
#    {'common': False, 'text': '塵入れ', 'tags': []},
#    {'common': False, 'text': 'ゴミ入', 'tags': []},
#    {'common': False, 'text': 'ごみ入', 'tags': []},
#    {'common': False, 'text': '塵入', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ゴミいれ',
#     'tags': [],
#     'appliesToKanji': ['ゴミ入れ', 'ゴミ入']},
#    {'common': False,
#     'text': 'ごみいれ',
#     'tags': [],
#     'appliesToKanji': ['ごみ入れ', '塵入れ', 'ごみ入', '塵入']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'trashcan'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'rubbish bin'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'dustbin'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'ashcan'}]}]},
#  {'id': '1006020',
#   'kanji': [{'common': False, 'text': 'じろじろ見る', 'tags': []},
#    {'common': False, 'text': 'ジロジロ見る', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'じろじろみる',
#     'tags': [],
#     'appliesToKanji': ['じろじろ見る']},
#    {'common': False,
#     'text': 'ジロジロみる',
#     'tags': [],
#     'appliesToKanji': ['ジロジロ見る']}],
#   'sense': [{'partOfSpeech': ['exp', 'v1'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to stare at'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to look hard at'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to look up and down'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to scrutinize'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to scrutinise'}]}]},
#  {'id': '1009510',
#   'kanji': [{'common': False, 'text': '何じゃそりゃ', 'tags': []},
#    {'common': False, 'text': '何じゃそら', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'なんじゃそりゃ',
#     'tags': [],
#     'appliesToKanji': ['何じゃそりゃ']},
#    {'common': False,
#     'text': 'なんじゃそら',
#     'tags': [],
#     'appliesToKanji': ['何じゃそら']}],
#   'sense': [{'partOfSpeech': ['exp'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['col', 'uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': "what's that?"},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'what the...'}]}]},
#  {'id': '1010840',
#   'kanji': [{'common': False, 'text': 'ピカピカ光る', 'tags': []},
#    {'common': False, 'text': 'ぴかぴか光る', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ピカピカひかる',
#     'tags': [],
#     'appliesToKanji': ['ピカピカ光る']},
#    {'common': False,
#     'text': 'ぴかぴかひかる',
#     'tags': [],
#     'appliesToKanji': ['ぴかぴか光る']}],
#   'sense': [{'partOfSpeech': ['exp', 'v5r'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to sparkle'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to glitter'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to twinkle'}]}]},
#  {'id': '1010850',
#   'kanji': [{'common': False, 'text': 'ピクピク動く', 'tags': []},
#    {'common': False, 'text': 'ぴくぴく動く', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ピクピクうごく',
#     'tags': [],
#     'appliesToKanji': ['ピクピク動く']},
#    {'common': False,
#     'text': 'ぴくぴくうごく',
#     'tags': [],
#     'appliesToKanji': ['ぴくぴく動く']}],
#   'sense': [{'partOfSpeech': ['exp', 'v5k'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'to jerk'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to wiggle'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to twitch'}]}]},
#  {'id': '1010930',
#   'kanji': [{'common': False, 'text': 'ピヨピヨ鳴く', 'tags': []},
#    {'common': False, 'text': 'ぴよぴよ鳴く', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ピヨピヨなく',
#     'tags': [],
#     'appliesToKanji': ['ピヨピヨ鳴く']},
#    {'common': False,
#     'text': 'ぴよぴよなく',
#     'tags': [],
#     'appliesToKanji': ['ぴよぴよ鳴く']}],
#   'sense': [{'partOfSpeech': ['exp', 'v5k'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'to peep'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to cheep'}]}]},
#  {'id': '1011520',
#   'kanji': [{'common': False, 'text': 'ベロベロ舐める', 'tags': []},
#    {'common': False, 'text': 'べろべろ舐める', 'tags': []},
#    {'common': False, 'text': 'べろべろ嘗める', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ベロベロなめる',
#     'tags': [],
#     'appliesToKanji': ['ベロベロ舐める']},
#    {'common': False,
#     'text': 'べろべろなめる',
#     'tags': [],
#     'appliesToKanji': ['べろべろ舐める', 'べろべろ嘗める']}],
#   'sense': [{'partOfSpeech': ['exp', 'v1'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to lick something up'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to lap something up'}]}]},
#  {'id': '1011570',
#   'kanji': [{'common': False, 'text': 'ペテン師', 'tags': []},
#    {'common': False, 'text': 'ぺてん師', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ペテンし',
#     'tags': [],
#     'appliesToKanji': ['ペテン師']},
#    {'common': False, 'text': 'ぺてんし', 'tags': [], 'appliesToKanji': ['ぺてん師']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'swindler'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'imposter'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'crook'}]}]},
#  {'id': '1011970',
#   'kanji': [{'common': False, 'text': 'ポタポタ落ちる', 'tags': []},
#    {'common': False, 'text': 'ぽたぽた落ちる', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ポタポタおちる',
#     'tags': [],
#     'appliesToKanji': ['ポタポタ落ちる']},
#    {'common': False,
#     'text': 'ぽたぽたおちる',
#     'tags': [],
#     'appliesToKanji': ['ぽたぽた落ちる']}],
#   'sense': [{'partOfSpeech': ['exp', 'v1'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['ぽたぽた', 1]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to fall in drops'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to drip down'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to trickle down'}]}]},
#  {'id': '1012040',
#   'kanji': [{'common': False, 'text': 'ポン引き', 'tags': []},
#    {'common': False, 'text': 'ぽん引き', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ポンびき',
#     'tags': [],
#     'appliesToKanji': ['ポン引き']},
#    {'common': False, 'text': 'ポンぴき', 'tags': [], 'appliesToKanji': ['ポン引き']},
#    {'common': False, 'text': 'ぽんびき', 'tags': [], 'appliesToKanji': ['ぽん引き']},
#    {'common': False, 'text': 'ぽんぴき', 'tags': [], 'appliesToKanji': ['ぽん引き']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'tout'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'swindler'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'con-man'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'pimp'}]}]},
#  {'id': '1021330',
#   'kanji': [{'common': False, 'text': 'イスラム原理主義', 'tags': []},
#    {'common': False, 'text': 'イスラーム原理主義', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'イスラムげんりしゅぎ',
#     'tags': [],
#     'appliesToKanji': ['イスラム原理主義']},
#    {'common': False,
#     'text': 'イスラームげんりしゅぎ',
#     'tags': [],
#     'appliesToKanji': ['イスラーム原理主義']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Islamic fundamentalism'}]}]},
#  {'id': '1034170',
#   'kanji': [{'common': False, 'text': 'オギノ式', 'tags': []},
#    {'common': False, 'text': '荻野式', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'オギノしき',
#     'tags': [],
#     'appliesToKanji': ['オギノ式']},
#    {'common': False, 'text': 'おぎのしき', 'tags': [], 'appliesToKanji': ['荻野式']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Ogino method (of birth control)'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'rhythm method'}]}]},
#  {'id': '1037740',
#   'kanji': [{'common': False, 'text': 'カツ丼', 'tags': []},
#    {'common': False, 'text': 'かつ丼', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'カツどん',
#     'tags': [],
#     'appliesToKanji': ['カツ丼']},
#    {'common': False, 'text': 'かつどん', 'tags': [], 'appliesToKanji': ['かつ丼']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['カツ']],
#     'antonym': [],
#     'field': ['food'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'katsudon'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': 'explanation',
#       'text': 'pork cutlet served on top of a bowl of rice'}]}]},
#  {'id': '1038000',
#   'kanji': [{'common': False, 'text': 'カバー曲', 'tags': []},
#    {'common': False, 'text': 'カヴァー曲', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'カバーきょく',
#     'tags': [],
#     'appliesToKanji': ['カバー曲']},
#    {'common': False,
#     'text': 'カヴァーきょく',
#     'tags': [],
#     'appliesToKanji': ['カヴァー曲']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': "cover song (remake of another artist's song)"}]}]},
#  {'id': '1038270',
#   'kanji': [{'common': False, 'text': 'カポジ肉腫', 'tags': []},
#    {'common': False, 'text': 'カポシ肉腫', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'カポジにくしゅ',
#     'tags': [],
#     'appliesToKanji': ['カポジ肉腫']},
#    {'common': False,
#     'text': 'カポシにくしゅ',
#     'tags': [],
#     'appliesToKanji': ['カポシ肉腫']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': "Kaposi's sarcoma"}]}]},
#  {'id': '1039630',
#   'kanji': [{'common': False, 'text': 'か行', 'tags': []},
#    {'common': False, 'text': 'カ行', 'tags': []},
#    {'common': False, 'text': '加行', 'tags': ['ateji', 'rK']}],
#   'kana': [{'common': False,
#     'text': 'かぎょう',
#     'tags': [],
#     'appliesToKanji': ['か行', '加行']},
#    {'common': False, 'text': 'カぎょう', 'tags': [], 'appliesToKanji': ['カ行']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'the "ka" column of the Japanese syllabary table (ka, ki, ku, ke, ko)'}]}]},
#  {'id': '1043200',
#   'kanji': [{'common': False, 'text': 'ギリシャ神話', 'tags': []},
#    {'common': False, 'text': 'ギリシア神話', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ギリシャしんわ',
#     'tags': [],
#     'appliesToKanji': ['ギリシャ神話']},
#    {'common': False,
#     'text': 'ギリシアしんわ',
#     'tags': [],
#     'appliesToKanji': ['ギリシア神話']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Greek mythology'}]}]},
#  {'id': '1043210',
#   'kanji': [{'common': False, 'text': 'ギリシャ文字', 'tags': []},
#    {'common': False, 'text': 'ギリシア文字', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ギリシャもじ',
#     'tags': [],
#     'appliesToKanji': ['ギリシャ文字']},
#    {'common': False,
#     'text': 'ギリシアもじ',
#     'tags': [],
#     'appliesToKanji': ['ギリシア文字']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Greek letter'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Greek alphabet'}]}]},
#  {'id': '1053560',
#   'kanji': [{'common': False, 'text': 'コンピュータ化', 'tags': []},
#    {'common': False, 'text': 'コンピューター化', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'コンピュータか',
#     'tags': [],
#     'appliesToKanji': ['コンピュータ化']},
#    {'common': False,
#     'text': 'コンピューターか',
#     'tags': [],
#     'appliesToKanji': ['コンピューター化']}],
#   'sense': [{'partOfSpeech': ['n', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'computerization'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'computerisation'}]}]},
#  {'id': '1053570',
#   'kanji': [{'common': False, 'text': 'コンピュータ用語', 'tags': []},
#    {'common': False, 'text': 'コンピューター用語', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'コンピュータようご',
#     'tags': [],
#     'appliesToKanji': ['コンピュータ用語']},
#    {'common': False,
#     'text': 'コンピューターようご',
#     'tags': [],
#     'appliesToKanji': ['コンピューター用語']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'computer terminology'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'computer term'}]}]},
#  {'id': '1058890',
#   'kanji': [{'common': False, 'text': 'さ行', 'tags': []},
#    {'common': False, 'text': 'サ行', 'tags': []},
#    {'common': False, 'text': '左行', 'tags': ['ateji', 'rK']},
#    {'common': False, 'text': '佐行', 'tags': ['ateji', 'rK']}],
#   'kana': [{'common': False,
#     'text': 'さぎょう',
#     'tags': [],
#     'appliesToKanji': ['さ行', '左行', '佐行']},
#    {'common': False, 'text': 'サぎょう', 'tags': [], 'appliesToKanji': ['サ行']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'the "sa" column of the Japanese syllabary table (sa, shi, su, se, so)'}]}]},
#  {'id': '1061740',
#   'kanji': [{'common': True, 'text': 'シャボン玉', 'tags': []},
#    {'common': False, 'text': 'しゃぼん玉', 'tags': []}],
#   'kana': [{'common': True,
#     'text': 'シャボンだま',
#     'tags': [],
#     'appliesToKanji': ['シャボン玉']},
#    {'common': False,
#     'text': 'しゃぼんだま',
#     'tags': [],
#     'appliesToKanji': ['しゃぼん玉']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'soap bubble'}]}]},
#  {'id': '1076620',
#   'kanji': [{'common': False, 'text': 'た行', 'tags': []},
#    {'common': False, 'text': 'タ行', 'tags': []},
#    {'common': False, 'text': '多行', 'tags': ['ateji', 'rK']}],
#   'kana': [{'common': False,
#     'text': 'たぎょう',
#     'tags': [],
#     'appliesToKanji': ['た行', '多行']},
#    {'common': False, 'text': 'タぎょう', 'tags': [], 'appliesToKanji': ['タ行']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'the "ta" column of the Japanese syllabary table (ta, chi, tsu, te, to)'}]}]},
#  {'id': '1077700',
#   'kanji': [{'common': False, 'text': 'チクチク痛む', 'tags': []},
#    {'common': False, 'text': 'ちくちく痛む', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'チクチクいたむ',
#     'tags': [],
#     'appliesToKanji': ['チクチク痛む']},
#    {'common': False,
#     'text': 'ちくちくいたむ',
#     'tags': [],
#     'appliesToKanji': ['ちくちく痛む']}],
#   'sense': [{'partOfSpeech': ['exp', 'v5m'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to prickle'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to tingle'}]}]},
#  {'id': '1083750',
#   'kanji': [{'common': False, 'text': 'デフォルト値', 'tags': []},
#    {'common': False, 'text': 'デフォールト値', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'デフォルトち',
#     'tags': [],
#     'appliesToKanji': ['デフォルト値']},
#    {'common': False,
#     'text': 'デフォールトち',
#     'tags': [],
#     'appliesToKanji': ['デフォールト値']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'default value'}]}]},
#  {'id': '1087390',
#   'kanji': [{'common': False, 'text': 'トロイの木馬', 'tags': []},
#    {'common': False, 'text': 'トロイアの木馬', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'トロイのもくば',
#     'tags': [],
#     'appliesToKanji': ['トロイの木馬']},
#    {'common': False,
#     'text': 'トロイアのもくば',
#     'tags': [],
#     'appliesToKanji': ['トロイアの木馬']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Trojan horse'}]}]},
#  {'id': '1096940',
#   'kanji': [{'common': False, 'text': 'は行', 'tags': []},
#    {'common': False, 'text': 'ハ行', 'tags': []},
#    {'common': False, 'text': '波行', 'tags': ['ateji', 'rK']}],
#   'kana': [{'common': False,
#     'text': 'はぎょう',
#     'tags': [],
#     'appliesToKanji': ['は行', '波行']},
#    {'common': False, 'text': 'ハぎょう', 'tags': [], 'appliesToKanji': ['ハ行']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'the "ha" column of the Japanese syllabary table (ha, hi, fu, he, ho)'}]}]},
#  {'id': '1103690',
#   'kanji': [{'common': False, 'text': 'ヒッグス機構', 'tags': []},
#    {'common': False, 'text': 'ヒグス機構', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ヒッグスきこう',
#     'tags': [],
#     'appliesToKanji': ['ヒッグス機構']},
#    {'common': False,
#     'text': 'ヒグスきこう',
#     'tags': [],
#     'appliesToKanji': ['ヒグス機構']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': ['physics'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Higgs mechanism'}]}]},
#  {'id': '1105980',
#   'kanji': [{'common': False, 'text': 'びらん剤', 'tags': []},
#    {'common': False, 'text': '糜爛剤', 'tags': []},
#    {'common': False, 'text': 'ビラン剤', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'びらんざい',
#     'tags': [],
#     'appliesToKanji': ['びらん剤', '糜爛剤']},
#    {'common': False, 'text': 'ビランざい', 'tags': [], 'appliesToKanji': ['ビラン剤']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'blister agent'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'vesicant'}]}]},
#  {'id': '1108140',
#   'kanji': [{'common': False, 'text': 'ファジー理論', 'tags': []},
#    {'common': False, 'text': 'ファジィ理論', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ファジーりろん',
#     'tags': [],
#     'appliesToKanji': ['ファジー理論']},
#    {'common': False,
#     'text': 'ファジィりろん',
#     'tags': [],
#     'appliesToKanji': ['ファジィ理論']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'fuzzy theory'}]}]},
#  {'id': '1121330',
#   'kanji': [{'common': False, 'text': 'ペルシャ語', 'tags': []},
#    {'common': False, 'text': 'ペルシア語', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ペルシャご',
#     'tags': [],
#     'appliesToKanji': ['ペルシャ語']},
#    {'common': False,
#     'text': 'ペルシアご',
#     'tags': [],
#     'appliesToKanji': ['ペルシア語']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Persian (language)'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'Farsi'}]}]},
#  {'id': '1130360',
#   'kanji': [{'common': False, 'text': 'ま行', 'tags': []},
#    {'common': False, 'text': 'マ行', 'tags': []},
#    {'common': False, 'text': '末行', 'tags': ['ateji', 'rK']},
#    {'common': False, 'text': '麻行', 'tags': ['ateji', 'rK']}],
#   'kana': [{'common': False,
#     'text': 'まぎょう',
#     'tags': [],
#     'appliesToKanji': ['ま行', '末行', '麻行']},
#    {'common': False, 'text': 'マぎょう', 'tags': [], 'appliesToKanji': ['マ行']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'the "ma" column of the Japanese syllabary table (ma, mi, mu, me, mo)'}]}]},
#  {'id': '1135595',
#   'kanji': [{'common': False, 'text': 'フッ化物', 'tags': []},
#    {'common': False, 'text': '弗化物', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'フッかぶつ',
#     'tags': [],
#     'appliesToKanji': ['フッ化物']},
#    {'common': False, 'text': 'ふっかぶつ', 'tags': [], 'appliesToKanji': ['弗化物']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'fluoride'}]}]},
#  {'id': '1136480',
#   'kanji': [{'common': False, 'text': 'や行', 'tags': []},
#    {'common': False, 'text': 'ヤ行', 'tags': []},
#    {'common': False, 'text': '也行', 'tags': ['ateji', 'rK']},
#    {'common': False, 'text': '夜行', 'tags': ['ateji', 'rK']}],
#   'kana': [{'common': False,
#     'text': 'やぎょう',
#     'tags': [],
#     'appliesToKanji': ['や行', '也行', '夜行']},
#    {'common': False, 'text': 'ヤぎょう', 'tags': [], 'appliesToKanji': ['ヤ行']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'the "ya" column of the Japanese syllabary table (ya, yu, yo)'}]}]},
#  {'id': '1140420',
#   'kanji': [{'common': False, 'text': 'ら行', 'tags': []},
#    {'common': False, 'text': 'ラ行', 'tags': []},
#    {'common': False, 'text': '良行', 'tags': ['ateji', 'rK']}],
#   'kana': [{'common': False,
#     'text': 'らぎょう',
#     'tags': [],
#     'appliesToKanji': ['ら行', '良行']},
#    {'common': False, 'text': 'ラぎょう', 'tags': [], 'appliesToKanji': ['ラ行']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'the "ra" column of the Japanese syllabary table (ra, ri, ru, re, ro)'}]}]},
#  {'id': '1143540',
#   'kanji': [{'common': False, 'text': 'リン酸', 'tags': []},
#    {'common': False, 'text': '燐酸', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'リンさん',
#     'tags': [],
#     'appliesToKanji': ['リン酸']},
#    {'common': False, 'text': 'りんさん', 'tags': [], 'appliesToKanji': ['燐酸']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'phosphoric acid (H3PO4)'}]}]},
#  {'id': '1149580',
#   'kanji': [{'common': False, 'text': 'βカロテン', 'tags': []},
#    {'common': False, 'text': 'βカロチン', 'tags': []},
#    {'common': False, 'text': 'β-カロテン', 'tags': []},
#    {'common': False, 'text': 'β-カロチン', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ベータカロテン',
#     'tags': [],
#     'appliesToKanji': ['βカロテン', 'β-カロテン']},
#    {'common': False,
#     'text': 'ベータカロチン',
#     'tags': [],
#     'appliesToKanji': ['βカロチン', 'β-カロチン']},
#    {'common': False,
#     'text': 'ベタカロテン',
#     'tags': ['ik'],
#     'appliesToKanji': ['βカロテン', 'β-カロテン']},
#    {'common': False,
#     'text': 'ベタカロチン',
#     'tags': ['ik'],
#     'appliesToKanji': ['βカロチン', 'β-カロチン']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'beta-carotene'}]}]},
#  {'id': '1149980',
#   'kanji': [{'common': False, 'text': '亜砒酸', 'tags': []},
#    {'common': False, 'text': '亜ヒ酸', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'あひさん',
#     'tags': [],
#     'appliesToKanji': ['亜砒酸']},
#    {'common': False, 'text': 'あヒさん', 'tags': [], 'appliesToKanji': ['亜ヒ酸']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'arsenious acid'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'arsenous acid (H3AsO3)'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['col'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'arsenic trioxide'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'white arsenic (As2O3)'}]}]},
#  {'id': '1150900',
#   'kanji': [{'common': False, 'text': '愛想のいい', 'tags': []},
#    {'common': False, 'text': '愛想の良い', 'tags': []},
#    {'common': False, 'text': '愛想のよい', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'あいそのいい',
#     'tags': [],
#     'appliesToKanji': ['愛想のいい', '愛想の良い']},
#    {'common': False,
#     'text': 'あいそのよい',
#     'tags': [],
#     'appliesToKanji': ['愛想の良い', '愛想のよい']}],
#   'sense': [{'partOfSpeech': ['exp', 'adj-ix'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'affable'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'amiable'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'sociable'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'agreeable'}]}]},
#  {'id': '1151500',
#   'kanji': [{'common': False, 'text': '悪ガキ', 'tags': []},
#    {'common': False, 'text': '悪餓鬼', 'tags': []},
#    {'common': False, 'text': '悪がき', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'わるガキ',
#     'tags': [],
#     'appliesToKanji': ['悪ガキ']},
#    {'common': False,
#     'text': 'わるがき',
#     'tags': [],
#     'appliesToKanji': ['悪餓鬼', '悪がき']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'brat'}]}]},
#  {'id': '1162000',
#   'kanji': [{'common': False, 'text': '１コマ', 'tags': []},
#    {'common': False, 'text': '一コマ', 'tags': []},
#    {'common': False, 'text': '１こま', 'tags': []},
#    {'common': False, 'text': '一こま', 'tags': []},
#    {'common': False, 'text': '一齣', 'tags': []},
#    {'common': False, 'text': '一駒', 'tags': ['iK']}],
#   'kana': [{'common': False,
#     'text': 'ひとコマ',
#     'tags': [],
#     'appliesToKanji': ['１コマ', '一コマ']},
#    {'common': False,
#     'text': 'ひとこま',
#     'tags': [],
#     'appliesToKanji': ['１こま', '一こま', '一齣', '一駒']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'one scene'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'one frame'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'one shot'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'one exposure'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'one cell'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'one panel (comic)'}]}]},
#  {'id': '1165600',
#   'kanji': [{'common': True, 'text': '一年中', 'tags': []},
#    {'common': False, 'text': '１年中', 'tags': []},
#    {'common': False, 'text': '一年じゅう', 'tags': []},
#    {'common': False, 'text': '一年ぢゅう', 'tags': []}],
#   'kana': [{'common': True,
#     'text': 'いちねんじゅう',
#     'tags': [],
#     'appliesToKanji': ['一年中', '１年中', '一年じゅう']},
#    {'common': False,
#     'text': 'いちねんぢゅう',
#     'tags': [],
#     'appliesToKanji': ['一年中', '１年中', '一年ぢゅう']}],
#   'sense': [{'partOfSpeech': ['n', 'adv'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'all year round'}]}]},
#  {'id': '1172180',
#   'kanji': [{'common': False, 'text': '卯年', 'tags': []},
#    {'common': False, 'text': 'うさぎ年', 'tags': []},
#    {'common': False, 'text': 'ウサギ年', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'うさぎどし',
#     'tags': [],
#     'appliesToKanji': ['卯年', 'うさぎ年']},
#    {'common': False, 'text': 'うどし', 'tags': [], 'appliesToKanji': ['卯年']},
#    {'common': False, 'text': 'ウサギどし', 'tags': [], 'appliesToKanji': ['ウサギ年']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'year of the Hare'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'year of the Rabbit'}]}]},
#  {'id': '1172620',
#   'kanji': [{'common': False, 'text': '運がいい', 'tags': []},
#    {'common': False, 'text': '運が良い', 'tags': []},
#    {'common': False, 'text': '運がよい', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'うんがいい',
#     'tags': [],
#     'appliesToKanji': ['運がいい', '運が良い']},
#    {'common': False,
#     'text': 'うんがよい',
#     'tags': [],
#     'appliesToKanji': ['運が良い', '運がよい']}],
#   'sense': [{'partOfSpeech': ['exp', 'adj-ix'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'lucky'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'fortunate'}]}]},
#  {'id': '1173320',
#   'kanji': [{'common': False, 'text': 'えごま油', 'tags': []},
#    {'common': False, 'text': 'エゴマ油', 'tags': []},
#    {'common': False, 'text': '荏胡麻油', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'えごまあぶら',
#     'tags': [],
#     'appliesToKanji': ['えごま油', '荏胡麻油']},
#    {'common': False, 'text': 'エゴマあぶら', 'tags': [], 'appliesToKanji': ['エゴマ油']},
#    {'common': False,
#     'text': 'えごまゆ',
#     'tags': [],
#     'appliesToKanji': ['えごま油', '荏胡麻油']},
#    {'common': False, 'text': 'エゴマゆ', 'tags': [], 'appliesToKanji': ['エゴマ油']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'perilla oil'}]}]},
#  {'id': '1178600',
#   'kanji': [{'common': False, 'text': '鉛筆削り', 'tags': []},
#    {'common': False, 'text': 'えんぴつ削り', 'tags': []},
#    {'common': False, 'text': 'エンピツ削り', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'えんぴつけずり',
#     'tags': [],
#     'appliesToKanji': ['鉛筆削り', 'えんぴつ削り']},
#    {'common': False,
#     'text': 'エンピツけずり',
#     'tags': [],
#     'appliesToKanji': ['エンピツ削り']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'pencil sharpener'}]}]},
#  {'id': '1178640',
#   'kanji': [{'common': False, 'text': '塩化ビニール', 'tags': []},
#    {'common': False, 'text': '塩化ビニル', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'えんかビニール',
#     'tags': [],
#     'appliesToKanji': ['塩化ビニール']},
#    {'common': False,
#     'text': 'えんかビニル',
#     'tags': [],
#     'appliesToKanji': ['塩化ビニル']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': ['chem'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'vinyl chloride'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'chloroethylene'}]}]},
#  {'id': '1180150',
#   'kanji': [{'common': False, 'text': '押しボタン', 'tags': []},
#    {'common': False, 'text': '押ボタン', 'tags': []},
#    {'common': False, 'text': '押し釦', 'tags': []},
#    {'common': False, 'text': '押釦', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'おしボタン',
#     'tags': [],
#     'appliesToKanji': ['押しボタン', '押ボタン']},
#    {'common': False,
#     'text': 'おしぼたん',
#     'tags': [],
#     'appliesToKanji': ['押し釦', '押釦']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'push button'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'push-button'}]}]},
#  {'id': '1182410',
#   'kanji': [{'common': False, 'text': '黄燐', 'tags': []},
#    {'common': False, 'text': '黄リン', 'tags': []},
#    {'common': False, 'text': '黄りん', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'おうりん',
#     'tags': [],
#     'appliesToKanji': ['黄燐', '黄りん']},
#    {'common': False, 'text': 'おうリン', 'tags': [], 'appliesToKanji': ['黄リン']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'yellow phosphorus'}]}]},
#  {'id': '1183790',
#   'kanji': [{'common': False, 'text': '音響カプラ', 'tags': []},
#    {'common': False, 'text': '音響カプラー', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'おんきょうカプラ',
#     'tags': [],
#     'appliesToKanji': ['音響カプラ']},
#    {'common': False,
#     'text': 'おんきょうカプラー',
#     'tags': [],
#     'appliesToKanji': ['音響カプラー']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': ['telec'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'acoustic coupler'}]}]},
#  {'id': '1188360',
#   'kanji': [{'common': True, 'text': '何だかんだ', 'tags': []},
#    {'common': False, 'text': '何だかだ', 'tags': []},
#    {'common': False, 'text': '何だ彼だ', 'tags': []}],
#   'kana': [{'common': True,
#     'text': 'なんだかんだ',
#     'tags': [],
#     'appliesToKanji': ['何だかんだ', '何だ彼だ']},
#    {'common': False,
#     'text': 'なんだかだ',
#     'tags': [],
#     'appliesToKanji': ['何だかだ', '何だ彼だ']}],
#   'sense': [{'partOfSpeech': ['adv'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'something or other'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'one thing or another'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'this or that'}]}]},
#  {'id': '1192250',
#   'kanji': [{'common': False, 'text': '家中', 'tags': []},
#    {'common': False, 'text': '家じゅう', 'tags': []},
#    {'common': False, 'text': 'うち中', 'tags': []},
#    {'common': False, 'text': 'いえ中', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'うちじゅう',
#     'tags': [],
#     'appliesToKanji': ['家中', '家じゅう', 'うち中']},
#    {'common': False, 'text': 'かちゅう', 'tags': [], 'appliesToKanji': ['家中']},
#    {'common': False,
#     'text': 'いえじゅう',
#     'tags': [],
#     'appliesToKanji': ['家中', '家じゅう', 'いえ中']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'whole family'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'entire family'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'all (members of) the family'}]},
#    {'partOfSpeech': ['adj-no', 'n'],
#     'appliesToKanji': ['*'],
# ...
#     'appliesToKanji': ['ひれ酒', '鰭酒']},
#    {'common': False, 'text': 'ヒレざけ', 'tags': [], 'appliesToKanji': ['ヒレ酒']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'hot sake with grilled fish fins (esp. fugu or sea bream)'}]}]},
#  {'id': '2573210',
#   'kanji': [{'common': False, 'text': '脇が甘い', 'tags': []},
#    {'common': False, 'text': 'わきが甘い', 'tags': []},
#    {'common': False, 'text': 'ワキが甘い', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'わきがあまい',
#     'tags': [],
#     'appliesToKanji': ['脇が甘い', 'わきが甘い']},
#    {'common': False,
#     'text': 'ワキがあまい',
#     'tags': [],
#     'appliesToKanji': ['ワキが甘い']}],
#   'sense': [{'partOfSpeech': ['exp', 'adj-i'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': ['sumo'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': "poor at preventing one's opponent from getting an underarm grip"}]},
#    {'partOfSpeech': ['exp', 'adj-i'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['id'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'having weak defenses'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': "off one's guard"},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'vulnerable (to attack)'}]}]},
#  {'id': '2573310',
#   'kanji': [{'common': False, 'text': '小猿', 'tags': []},
#    {'common': False, 'text': '子猿', 'tags': []},
#    {'common': False, 'text': '子ザル', 'tags': []},
#    {'common': False, 'text': '子ざる', 'tags': []},
#    {'common': False, 'text': '仔猿', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'こざる',
#     'tags': [],
#     'appliesToKanji': ['小猿', '子猿', '子ざる', '仔猿']},
#    {'common': False, 'text': 'こザル', 'tags': [], 'appliesToKanji': ['子ザル']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'baby monkey'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'small monkey'}]}]},
#  {'id': '2575670',
#   'kanji': [{'common': False, 'text': '体のいい', 'tags': []},
#    {'common': False, 'text': '体の良い', 'tags': []},
#    {'common': False, 'text': '体のよい', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ていのいい',
#     'tags': [],
#     'appliesToKanji': ['体のいい', '体の良い']},
#    {'common': False,
#     'text': 'ていのよい',
#     'tags': [],
#     'appliesToKanji': ['体の良い', '体のよい']}],
#   'sense': [{'partOfSpeech': ['exp', 'adj-ix'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'nice-looking'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'seemingly fine'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'nice-sounding'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'polite-sounding'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'plausible (e.g. excuse)'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'glib'}]}]},
#  {'id': '2577150',
#   'kanji': [{'common': False, 'text': '湯立て', 'tags': []},
#    {'common': False, 'text': '湯立ち', 'tags': []},
#    {'common': False, 'text': '湯立', 'tags': ['io']}],
#   'kana': [{'common': False,
#     'text': 'ゆだて',
#     'tags': [],
#     'appliesToKanji': ['湯立て', '湯立']},
#    {'common': False,
#     'text': 'ゆだち',
#     'tags': [],
#     'appliesToKanji': ['湯立ち', '湯立']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['巫女', 'みこ・2', 2]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Shinto ritual in which a shaman or priest soaks bamboo grass in boiling water and sprinkles the water on worshippers (originally a form of divination, later a purification ceremony, now primarily used to pray for good health)'}]}]},
#  {'id': '2579530',
#   'kanji': [{'common': False, 'text': 'ゴール朝', 'tags': []},
#    {'common': False, 'text': 'グール朝', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ゴールちょう',
#     'tags': [],
#     'appliesToKanji': ['ゴール朝']},
#    {'common': False,
#     'text': 'グールちょう',
#     'tags': [],
#     'appliesToKanji': ['グール朝']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['hist'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Ghurid dynasty (of south Asia; approx. 1148-1215)'}]}]},
#  {'id': '2579590',
#   'kanji': [{'common': False, 'text': 'トゥグルク朝', 'tags': []},
#    {'common': False, 'text': 'ツグルク朝', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'トゥグルクちょう',
#     'tags': [],
#     'appliesToKanji': ['トゥグルク朝']},
#    {'common': False,
#     'text': 'ツグルクちょう',
#     'tags': [],
#     'appliesToKanji': ['ツグルク朝']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['hist'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Tughluq dynasty (of India; 1320-1413)'}]}]},
#  {'id': '2579620',
#   'kanji': [{'common': False, 'text': 'ムガル帝国', 'tags': []},
#    {'common': False, 'text': 'ムガール帝国', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ムガルていこく',
#     'tags': [],
#     'appliesToKanji': ['ムガル帝国']},
#    {'common': False,
#     'text': 'ムガールていこく',
#     'tags': [],
#     'appliesToKanji': ['ムガール帝国']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['hist'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Mughal Empire'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'Mogul Empire'}]}]},
#  {'id': '2581400',
#   'kanji': [{'common': False, 'text': 'ノミ取り首輪', 'tags': []},
#    {'common': False, 'text': '蚤取り首輪', 'tags': []},
#    {'common': False, 'text': 'のみ取り首輪', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ノミとりくびわ',
#     'tags': [],
#     'appliesToKanji': ['ノミ取り首輪']},
#    {'common': False,
#     'text': 'のみとりくびわ',
#     'tags': [],
#     'appliesToKanji': ['蚤取り首輪', 'のみ取り首輪']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'flea collar'}]}]},
#  {'id': '2582030',
#   'kanji': [{'common': False, 'text': 'ワン公', 'tags': []},
#    {'common': False, 'text': 'わん公', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ワンこう',
#     'tags': [],
#     'appliesToKanji': ['ワン公']},
#    {'common': False, 'text': 'わんこう', 'tags': [], 'appliesToKanji': ['わん公']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['ワン']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['col'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'dog'}]}]},
#  {'id': '2582170',
#   'kanji': [{'common': False, 'text': '霰石', 'tags': []},
#    {'common': False, 'text': 'アラレ石', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'あられいし',
#     'tags': [],
#     'appliesToKanji': ['霰石']},
#    {'common': False, 'text': 'アラレいし', 'tags': [], 'appliesToKanji': ['アラレ石']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'aragonite'}]}]},
#  {'id': '2585120',
#   'kanji': [{'common': False, 'text': '真澄鏡', 'tags': []},
#    {'common': False, 'text': '真十鏡', 'tags': []},
#    {'common': False, 'text': '十寸鏡', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'まそかがみ',
#     'tags': [],
#     'appliesToKanji': ['真澄鏡', '真十鏡']},
#    {'common': False,
#     'text': 'ますかがみ',
#     'tags': [],
#     'appliesToKanji': ['真澄鏡', '十寸鏡']},
#    {'common': False, 'text': 'まそみかがみ', 'tags': [], 'appliesToKanji': ['真澄鏡']}],
#   'sense': [{'partOfSpeech': ['exp'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['真澄の鏡']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['arch'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'perfectly clear mirror'}]}]},
#  {'id': '2585900',
#   'kanji': [{'common': False, 'text': 'スンニ派', 'tags': []},
#    {'common': False, 'text': 'スンニー派', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'スンニは',
#     'tags': [],
#     'appliesToKanji': ['スンニ派']},
#    {'common': False,
#     'text': 'スンニーは',
#     'tags': [],
#     'appliesToKanji': ['スンニー派']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['スンナ派', 'スンナは']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'ara',
#       'full': True,
#       'wasei': False,
#       'text': None}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Sunni (Islam)'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'Sunnah'}]}]},
#  {'id': '2586310',
#   'kanji': [{'common': False, 'text': '支那語', 'tags': []},
#    {'common': False, 'text': 'シナ語', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'しなご',
#     'tags': [],
#     'appliesToKanji': ['支那語']},
#    {'common': False, 'text': 'シナご', 'tags': [], 'appliesToKanji': ['シナ語']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['中国語']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['obs'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Chinese (language)'}]}]},
#  {'id': '2589120',
#   'kanji': [{'common': False, 'text': '鼻ペチャ', 'tags': []},
#    {'common': False, 'text': '鼻ぺちゃ', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'はなペチャ',
#     'tags': [],
#     'appliesToKanji': ['鼻ペチャ']},
#    {'common': False, 'text': 'はなぺちゃ', 'tags': [], 'appliesToKanji': ['鼻ぺちゃ']}],
#   'sense': [{'partOfSpeech': ['n', 'adj-na', 'adj-no'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'small, flat nose'}]}]},
#  {'id': '2589380',
#   'kanji': [{'common': False, 'text': 'マリーセレスト号', 'tags': []},
#    {'common': False, 'text': 'マリーセレステ号', 'tags': []},
#    {'common': False, 'text': 'マリー・セレスト号', 'tags': []},
#    {'common': False, 'text': 'マリー・セレステ号', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'マリーセレストごう',
#     'tags': [],
#     'appliesToKanji': ['マリーセレスト号', 'マリー・セレスト号']},
#    {'common': False,
#     'text': 'マリーセレステごう',
#     'tags': [],
#     'appliesToKanji': ['マリーセレステ号', 'マリー・セレステ号']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['hist'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Mary Celeste (famous British ship found in 1872 without crew or passengers)'}]}]},
#  {'id': '2589760',
#   'kanji': [{'common': False, 'text': '居グセ', 'tags': []},
#    {'common': False, 'text': '居曲', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'いグセ',
#     'tags': [],
#     'appliesToKanji': ['居グセ']},
#    {'common': False, 'text': 'いぐせ', 'tags': [], 'appliesToKanji': ['居曲']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['曲', 'くせ・1', 1], ['仕手', 2]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'aural highlight of a noh play in which the main actor remains seated'}]}]},
#  {'id': '2589770',
#   'kanji': [{'common': False, 'text': '舞グセ', 'tags': []},
#    {'common': False, 'text': '舞曲', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'まいグセ',
#     'tags': [],
#     'appliesToKanji': ['舞グセ']},
#    {'common': False, 'text': 'まいぐせ', 'tags': [], 'appliesToKanji': ['舞曲']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['曲', 'くせ・1', 1], ['仕手', 2]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'aural highlight of a noh play in which the main actor dances'}]}]},
#  {'id': '2592160',
#   'kanji': [{'common': False, 'text': 'ヤケ腹', 'tags': []},
#    {'common': False, 'text': '自棄腹', 'tags': []},
#    {'common': False, 'text': '焼け腹', 'tags': []},
#    {'common': False, 'text': '焼腹', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ヤケばら',
#     'tags': [],
#     'appliesToKanji': ['ヤケ腹']},
#    {'common': False,
#     'text': 'やけばら',
#     'tags': [],
#     'appliesToKanji': ['自棄腹', '焼け腹', '焼腹']}],
#   'sense': [{'partOfSpeech': ['n', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'desperation'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'despair'}]}]},
#  {'id': '2592650',
#   'kanji': [{'common': False, 'text': '日焼けマシーン', 'tags': []},
#    {'common': False, 'text': '日焼けマシン', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'ひやけマシーン',
#     'tags': [],
#     'appliesToKanji': ['日焼けマシーン']},
#    {'common': False,
#     'text': 'ひやけマシン',
#     'tags': [],
#     'appliesToKanji': ['日焼けマシン']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'sunbed'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'tanning bed'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'tanning booth'}]}]},
#  ...]

# %%
words_multi_reading[:100]
# Out:
# [{'id': '1000040',
#   'kanji': [{'common': False, 'text': '〃', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'おなじ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'おなじく', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'ditto mark'}]}]},
#  {'id': '1000060',
#   'kanji': [{'common': False, 'text': '々', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'のま',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ノマ', 'tags': [], 'appliesToKanji': []}],
#   'sense': [{'partOfSpeech': ['unc'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['同の字点']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': 'explanation',
#       'text': 'kanji repetition mark'}]}]},
#  {'id': '1000090',
#   'kanji': [{'common': False, 'text': '○', 'tags': []},
#    {'common': False, 'text': '〇', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'まる',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['丸', 'まる・1', 1]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': ['sometimes used for zero'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'circle'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['二重丸']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': ['when marking a test, homework, etc.'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': '"correct"'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': '"good"'}]},
#    {'partOfSpeech': ['unc'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['〇〇', 1]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': ['placeholder used to censor individual characters or indicate a space to be filled in'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': '*'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': '_'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['句点']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'period'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'full stop'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['半濁点']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'handakuten (diacritic)'}]}]},
#  {'id': '1000200',
#   'kanji': [{'common': False, 'text': '阿吽の呼吸', 'tags': []},
#    {'common': False, 'text': 'あうんの呼吸', 'tags': []},
#    {'common': False, 'text': 'あ・うんの呼吸', 'tags': ['sK']}],
#   'kana': [{'common': False,
#     'text': 'あうんのこきゅう',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['exp', 'n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['id'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'the harmonizing, mentally and physically, of two parties engaged in an activity'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'singing from the same hymn-sheet'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'dancing to the same beat'}]}]},
#  {'id': '1000225',
#   'kanji': [{'common': False, 'text': '明白', 'tags': ['ateji', 'rK']},
#    {'common': False, 'text': '偸閑', 'tags': ['ateji', 'rK']},
#    {'common': False, 'text': '白地', 'tags': ['ateji', 'rK']}],
#   'kana': [{'common': False,
#     'text': 'あからさま',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adj-na', 'adj-no'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'plain'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'frank'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'candid'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'open'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'direct'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'straightforward'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'unabashed'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'blatant'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'flagrant'}]}]},
#  {'id': '1000230',
#   'kanji': [{'common': False, 'text': '明かん', 'tags': ['rK']}],
#   'kana': [{'common': False,
#     'text': 'あかん',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アカン', 'tags': [], 'appliesToKanji': []}],
#   'sense': [{'partOfSpeech': ['exp'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': ['ksb'],
#     'misc': ['uk'],
#     'info': ['commonly used with i-adjective inflections, e.g. あかんかった, あかんくない'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'useless'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'no good'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'hopeless'}]},
#    {'partOfSpeech': ['exp'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': ['ksb'],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'cannot'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'must not'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'not allowed'}]}]},
#  {'id': '1000260',
#   'kanji': [{'common': False, 'text': '悪どい', 'tags': ['ateji']},
#    {'common': False, 'text': '灰汁どい', 'tags': ['rK']}],
#   'kana': [{'common': False,
#     'text': 'あくどい',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adj-i'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['アクが強い', 2]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'gaudy'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'showy'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'garish'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'loud'}]},
#    {'partOfSpeech': ['adj-i'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'crooked'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'vicious'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'wicked'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'nasty'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'unscrupulous'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'dishonest'}]}]},
#  {'id': '1000300',
#   'kanji': [{'common': False, 'text': '遇う', 'tags': []},
#    {'common': False, 'text': '配う', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'あしらう',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['v5u', 'vt'],
#     'appliesToKanji': ['遇う'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to treat'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to handle'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to deal with'}]},
#    {'partOfSpeech': ['v5u', 'vt'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to arrange'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to decorate'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to dress'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to garnish'}]}]},
#  {'id': '1000310',
#   'kanji': [{'common': False, 'text': '馬酔木', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'あせび',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あしび', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あせぼ', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あせぶ', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アセビ', 'tags': [], 'appliesToKanji': []}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Japanese andromeda (Pieris japonica)'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'lily-of-the-valley'}]}]},
#  {'id': '1000320',
#   'kanji': [{'common': False, 'text': '彼処', 'tags': ['rK']},
#    {'common': False, 'text': '彼所', 'tags': ['rK']}],
#   'kana': [{'common': True,
#     'text': 'あそこ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あすこ', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'かしこ', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アソコ', 'tags': [], 'appliesToKanji': []},
#    {'common': False, 'text': 'あしこ', 'tags': ['ok'], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あこ', 'tags': ['ok'], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['どこ', 1], ['ここ', 1], ['そこ', 1]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': ['place physically distant from both speaker and listener'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'there'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'over there'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'that place'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'yonder'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'you-know-where'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['あそこ', 'あすこ', 'アソコ'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['col', 'uk', 'euph'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'genitals'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'private parts'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'nether regions'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['あれほど']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': ['something psychologically distant from both speaker and listener'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'that far'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'that much'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'that point'}]}]},
#  {'id': '1000360',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'あっさり',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アッサリ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'easily'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'readily'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'quickly'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'flatly (refuse)'}]},
#    {'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'lightly (seasoned food, applied make-up, etc.)'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'plainly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'simply'}]}]},
#  {'id': '1000390',
#   'kanji': [{'common': True, 'text': 'あっという間に', 'tags': []},
#    {'common': False, 'text': 'あっと言う間に', 'tags': []},
#    {'common': False, 'text': 'アッという間に', 'tags': ['sK']},
#    {'common': False, 'text': 'アッと言う間に', 'tags': ['sK']},
#    {'common': False, 'text': 'あっとゆう間に', 'tags': ['sK']},
#    {'common': False, 'text': 'アッとゆう間に', 'tags': ['sK']}],
#   'kana': [{'common': True,
#     'text': 'あっというまに',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['exp', 'adv'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'in an instant'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'in a flash'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'in the blink of an eye'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'in no time at all'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'just like that'}]}]},
#  {'id': '1000420',
#   'kanji': [{'common': False, 'text': '彼の', 'tags': ['rK']}],
#   'kana': [{'common': True, 'text': 'あの', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あん', 'tags': [], 'appliesToKanji': []}],
#   'sense': [{'partOfSpeech': ['adj-pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['どの'], ['この', 1], ['その', 1]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': ['someone or something distant from both speaker and listener, or situation unfamiliar to both speaker and listener'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'that'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'those'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'the'}]}]},
#  {'id': '1000430',
#   'kanji': [],
#   'kana': [{'common': True, 'text': 'あの', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': True, 'text': 'あのー', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あのう', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['int'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'say'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'well'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'um'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'er'}]}]},
#  {'id': '1000440',
#   'kanji': [{'common': True, 'text': 'あの人', 'tags': []},
#    {'common': False, 'text': '彼の人', 'tags': []}],
#   'kana': [{'common': True,
#     'text': 'あのひと',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': ["sometimes of one's spouse or partner"],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'he'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'she'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'that person'}]},
#    {'partOfSpeech': ['pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['arch'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'you'}]}]},
#  {'id': '1000450',
#   'kanji': [{'common': True, 'text': 'あの方', 'tags': []},
#    {'common': False, 'text': '彼の方', 'tags': []}],
#   'kana': [{'common': True,
#     'text': 'あのかた',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['hon'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'that gentleman'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'that lady'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'he'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'she'}]}]},
#  {'id': '1000480',
#   'kanji': [{'common': False, 'text': '阿呆陀羅', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'あほんだら',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あほだら', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アホンダラ', 'tags': [], 'appliesToKanji': []}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': ['ksb'],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'fool'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'oaf'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'airhead'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['あほだら'],
#     'related': [['あほだら経']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['abbr'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': 'explanation',
#       'text': 'type of fast-paced humorous singing mimicking the chanting of a Buddhist sutra, usually with lyrics satirizing current events'}]}]},
#  {'id': '1000490',
#   'kanji': [{'common': False, 'text': '甘子', 'tags': []},
#    {'common': False, 'text': '天魚', 'tags': []},
#    {'common': False, 'text': '雨子', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'あまご',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アマゴ', 'tags': [], 'appliesToKanji': []}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['皐月鱒']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'land-locked variety of red-spotted masu trout (Oncorhynchus masou ishikawae)'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'amago'}]}]},
#  {'id': '1000520',
#   'kanji': [],
#   'kana': [{'common': True, 'text': 'あら', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'あらー', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['int'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['fem'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'oh!'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'ah!'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'oh no'}]}]},
#  {'id': '1000525',
#   'kanji': [{'common': False, 'text': '𩺊', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'あら',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アラ', 'tags': [], 'appliesToKanji': []}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'saw-edged perch (Niphon spinosus)'}]}]},
#  {'id': '1000580',
#   'kanji': [{'common': False, 'text': '彼', 'tags': ['rK']},
#    {'common': False, 'text': '彼れ', 'tags': ['rK']}],
#   'kana': [{'common': True, 'text': 'あれ', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アレ', 'tags': ['sk'], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['これ', 1], ['それ', 1], ['どれ', 1]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': ['indicating something distant from both speaker and listener (in space, time or psychologically), or something understood without naming it directly'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'that'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'that thing'}]},
#    {'partOfSpeech': ['pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': ["used to refer to one's equals or inferiors"],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'that person'}]},
#    {'partOfSpeech': ['pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'then'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'that time'}]},
#    {'partOfSpeech': ['pn'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'that place (over there)'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['col', 'euph', 'uk'],
#     'info': ['oft. written as アレ'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': "down there (i.e. one's genitals)"}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['col', 'euph', 'uk'],
#     'info': ['oft. written as アレ'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'period'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'menses'}]}]},
#  {'id': '1000610',
#   'kanji': [{'common': False, 'text': 'いい年をして', 'tags': []},
#    {'common': False, 'text': 'いい歳をして', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'いいとしをして',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['exp'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['いい年して']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': '(in spite of) being old enough to know better'}]}]},
#  {'id': '1000620',
#   'kanji': [{'common': True, 'text': '否々', 'tags': []},
#    {'common': False, 'text': '否否', 'tags': []}],
#   'kana': [{'common': True,
#     'text': 'いやいや',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'いえいえ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['int'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'no!'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'no no!'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'no, not at all'}]}]},
#  {'id': '1000640',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'いかす',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'イカす', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['v5s', 'vi'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['col'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to be smart'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to be cool'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to be sharp'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to be stylish'}]}]},
#  {'id': '1000650',
#   'kanji': [{'common': False, 'text': 'いかなる場合でも', 'tags': []},
#    {'common': False, 'text': '如何なる場合でも', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'いかなるばあいでも',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['exp'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'in any case'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'whatever the case may be'}]}]},
#  {'id': '1000760',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'いざこざ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'イザコザ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'trouble'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'quarrel'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'difficulties'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'complication'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'tangle'}]}]},
#  {'id': '1000770',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イジイジ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'いじいじ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'hesitantly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'timidly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'diffidently'}]}]},
#  {'id': '1000790',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'いじましい',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'いぢましい',
#     'tags': ['rk'],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adj-i'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'stingy'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'petty'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'pathetic'}]},
#    {'partOfSpeech': ['adj-i'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['col'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'lovable'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'sweet'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'charming'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'touching'}]}]},
#  {'id': '1000810',
#   'kanji': [{'common': False, 'text': 'いじり回す', 'tags': []},
#    {'common': False, 'text': '弄り回す', 'tags': []},
#    {'common': False, 'text': '弄りまわす', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'いじりまわす',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['v5s', 'vt'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to tinker with'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to fumble with'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to fiddle with'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to twiddle'}]}]},
#  {'id': '1000820',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'いそいそ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'イソイソ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv-to', 'adv', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'cheerfully'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'joyously'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'joyfully'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'happily'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'lightheartedly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'excitedly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'eagerly'}]}]},
#  {'id': '1000830',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イチャイチャ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'いちゃいちゃ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'making out'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'necking'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'canoodling'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'fondling'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'flirting'}]}]},
#  {'id': '1000840',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'いちゃつく',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'イチャつく', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['v5k', 'vi'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to make out'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to neck'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to canoodle'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to fondle each other'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to flirt (with)'}]}]},
#  {'id': '1000910',
#   'kanji': [{'common': False, 'text': '嫌に', 'tags': []},
#    {'common': False, 'text': '厭に', 'tags': []}],
#   'kana': [{'common': False,
#     'text': 'いやに',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'awfully'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'terribly'}]}]},
#  {'id': '1000920',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'いらっしゃい',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'いらしゃい',
#     'tags': ['ik'],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['int'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['いらっしゃる', 1]],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['hon'],
#     'info': ['used as a polite imperative'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'come'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'go'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'stay'}]},
#    {'partOfSpeech': ['int'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['いらっしゃいませ']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'welcome'}]}]},
#  {'id': '1000930',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'いらっしゃいませ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'いらしゃいませ',
#     'tags': ['ik'],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['exp'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': ['used in shops, restaurants, etc.'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'welcome'}]}]},
#  {'id': '1000960',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'うじうじ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウジウジ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'indecisively'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'hesitantly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'irresolutely'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'wishy-washily'}]}]},
#  {'id': '1000970',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'うじゃうじゃ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウジャウジャ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'in swarms'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'in clusters'}]},
#    {'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'tediously'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'slowly'}]}]},
#  {'id': '1000980',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'うずうず',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウズウズ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'itching to do something'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'impatient'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'sorely tempted'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'eager'}]}]},
#  {'id': '1001000',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'うだうだ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウダウダ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'going on and on (about inconsequential things)'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'talking nonsense'}]},
#    {'partOfSpeech': ['adv', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'idling away the time'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'dawdling'}]}]},
#  {'id': '1001010',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'うっかり',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウッカリ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'carelessly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'thoughtlessly'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'inadvertently'}]}]},
#  {'id': '1001030',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'うとうと',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウトウト', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'うとっと', 'tags': ['sk'], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウトッと', 'tags': ['sk'], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウトっと', 'tags': ['sk'], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'falling into a doze'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'dozing off'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'nodding off'}]}]},
#  {'id': '1001040',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'うねうね',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウネウネ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'winding'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'meandering'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'zigzagging'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'zig-zag'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'in twists and turns'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'sinuously'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'tortuously'}]}]},
#  {'id': '1001060',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'うろうろ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウロウロ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'restlessly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'aimlessly'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'without purpose'}]},
#    {'partOfSpeech': ['vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['彷徨く']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to loiter'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to drift'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to hang about doing nothing'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to wander aimlessly'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to be restless'}]},
#    {'partOfSpeech': ['vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to be restless'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to fuss'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'to be in a fidget'}]}]},
#  {'id': '1001090',
#   'kanji': [],
#   'kana': [{'common': True, 'text': 'うん', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'うむ', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ううむ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['int'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'yes'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'yeah'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'uh huh'}]},
#    {'partOfSpeech': ['int'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'hum'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'hmmm'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'well'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'erm'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'huh?'}]},
#    {'partOfSpeech': ['int'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['うん'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': ['moan or groan (of pain)'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'oof'}]}]},
#  {'id': '1001100',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'うんこ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウンコ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n', 'vs', 'vi'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['chn'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'poop'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'poo'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'faeces'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'feces'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['sl'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'crap'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'trash'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'garbage'}]}]},
#  {'id': '1001110',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'うんざり',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'ウンザリ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adv', 'adv-to', 'vs'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['on-mim'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'tedious'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'boring'},
#      {'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'being fed up with'}]}]},
#  {'id': '1001120',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'ウンチ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'うんち', 'tags': [], 'appliesToKanji': ['*']}],
# ...
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンチョビー',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンチョビ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'anchovy'}]}]},
#  {'id': '1020380',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンツーカ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンツーカー', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'fre',
#       'full': True,
#       'wasei': False,
#       'text': None}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'en-tout-cas (track or tennis court surface made of clay and crushed brick)'}]}]},
#  {'id': '1020390',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'アンティーク',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'アンティック',
#     'tags': ['rk'],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンチック', 'tags': ['rk'], 'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'アンチーク',
#     'tags': ['rk'],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n', 'adj-na'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'fre',
#       'full': True,
#       'wasei': False,
#       'text': None}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'antique'}]}]},
#  {'id': '1020420',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンテナショップ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'アンテナ・ショップ',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'eng',
#       'full': True,
#       'wasei': True,
#       'text': 'antenna shop'}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'shop selling local specialties from other regions'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['パイロットショップ']],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': ['orig. meaning'],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'shop used for testing sales of new products'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'showroom'}]}]},
#  {'id': '1020460',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アントレ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アントレー', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'fre',
#       'full': True,
#       'wasei': False,
#       'text': None}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'entrée'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['アントレ'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['abbr'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'entrepreneurship'}]}]},
#  {'id': '1020470',
#   'kanji': [{'common': False, 'text': '＆', 'tags': []},
#    {'common': False, 'text': 'ａｎｄ', 'tags': []},
#    {'common': False, 'text': 'ＡＮＤ', 'tags': []}],
#   'kana': [{'common': True,
#     'text': 'アンド',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'エンド', 'tags': ['ik'], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['conj'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['uk'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'and'}]},
#    {'partOfSpeech': ['n'],
#     'appliesToKanji': ['ＡＮＤ'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': ['logic'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'AND (Boolean operator)'}]}]},
#  {'id': '1020480',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンドゥ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンドゥー', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n', 'vs', 'vt', 'vi'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': ['comp'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng', 'gender': None, 'type': None, 'text': 'undoing'},
#      {'lang': 'eng', 'gender': None, 'type': None, 'text': 'undo'}]}]},
#  {'id': '1020490',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンドゥトロワ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アン・ドゥ・トロワ', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'アンドウトラワ',
#     'tags': ['sk'],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['exp'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'fre',
#       'full': True,
#       'wasei': False,
#       'text': 'un, deux, trois'}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'one, two, three'}]}]},
#  {'id': '1020580',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンパイア',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンパイヤ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'umpire'}]}]},
#  {'id': '1020600',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンビバレンス',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンビヴァレンス', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n', 'adj-no'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'ambivalence'}]}]},
#  {'id': '1020610',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンファンテリブル',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'アンファン・テリブル',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'fre',
#       'full': True,
#       'wasei': False,
#       'text': None}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'enfant terrible'}]}]},
#  {'id': '1020640',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンブレラカット',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'アンブレラ・カット',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'umbrella cut'}]}]},
#  {'id': '1020660',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンプリファイアー',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンプリファイア', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンプリファイヤー', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンプリファイヤ', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'amplifier'}]}]},
#  {'id': '1020680',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'アンプレアブル',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンプレヤブル', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False, 'text': 'アンプレイアブル', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['adj-no', 'n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': ['golf'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'unplayable (ball)'}]}]},
#  {'id': '1020820',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イージーオーダー',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'イージー・オーダー',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'eng',
#       'full': True,
#       'wasei': True,
#       'text': 'easy order'}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'semi-custom-made suit'}]}]},
#  {'id': '1020830',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イージーケア',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'イージー・ケア', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'easy care'}]}]},
#  {'id': '1020850',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イージーペイメント',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'イージー・ペイメント',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'easy payment (system)'}]}]},
#  {'id': '1020860',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イージーリスニング',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'イージー・リスニング',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': ['abbr'],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'easy listening music'}]}]},
#  {'id': '1020870',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イージーリスニングミュージック',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'イージー・リスニング・ミュージック',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'easy listening music'}]}]},
#  {'id': '1020890',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イースタングリップ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'イースタン・グリップ',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'eastern grip (in tennis)'}]}]},
#  {'id': '1020900',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イースタンリーグ',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'イースタン・リーグ',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [['ウエスタンリーグ']],
#     'antonym': [],
#     'field': ['baseb'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Eastern League (one of the two minor leagues of Japanese professional baseball)'}]}]},
#  {'id': '1020930',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イーストコースト',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'イースト・コースト',
#     'tags': [],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'east coast'}]}]},
#  {'id': '1020970',
#   'kanji': [],
#   'kana': [{'common': False,
#     'text': 'イーブンパー',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'イーブン・パー', 'tags': [], 'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': ['golf'],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'even par'}]}]},
#  {'id': '1021010',
#   'kanji': [],
#   'kana': [{'common': True,
#     'text': 'イエス',
#     'tags': [],
#     'appliesToKanji': ['*']},
#    {'common': False, 'text': 'エス', 'tags': [], 'appliesToKanji': ['*']},
#    {'common': False,
#     'text': 'イエースース',
#     'tags': ['ik'],
#     'appliesToKanji': ['*']}],
#   'sense': [{'partOfSpeech': ['n'],
#     'appliesToKanji': ['*'],
#     'appliesToKana': ['*'],
#     'related': [],
#     'antonym': [],
#     'field': [],
#     'dialect': [],
#     'misc': [],
#     'info': [],
#     'languageSource': [{'lang': 'lat',
#       'full': True,
#       'wasei': False,
#       'text': 'Iesus'}],
#     'gloss': [{'lang': 'eng',
#       'gender': None,
#       'type': None,
#       'text': 'Jesus (Christ)'}]}]},
#  ...]

# %%
words_tags = []
for i, word in enumerate(dict_data["words"]):
    add = True
    for kana in word["kana"] + word["kanji"]:
        if len(kana["tags"]) == 0:
            add = False
    if add:
        words_tags.append(word)

# %%
dict_data["tags"]['sK']
# Out:
# 'search-only kanji form'

# %%
words_tags[5]
# Out:
# {'id': '2009310',
#  'kanji': [{'common': False, 'text': '泥濘む', 'tags': ['rK']}],
#  'kana': [{'common': False,
#    'text': 'ぬかるむ',
#    'tags': ['gikun'],
#    'appliesToKanji': ['*']}],
#  'sense': [{'partOfSpeech': ['v5m', 'vi'],
#    'appliesToKanji': ['*'],
#    'appliesToKana': ['*'],
#    'related': [],
#    'antonym': [],
#    'field': [],
#    'dialect': [],
#    'misc': ['uk'],
#    'info': [],
#    'languageSource': [],
#    'gloss': [{'lang': 'eng',
#      'gender': None,
#      'type': None,
#      'text': 'to be muddy'},
#     {'lang': 'eng', 'gender': None, 'type': None, 'text': 'to be slushy'}]}]}

# %%
words_multi_reading = []
for i, word in enumerate(dict_data["words"]):
    if len(word["kanji"]) > 1 or len(word["kana"]) > 1:
        words_multi_reading.append(word)
